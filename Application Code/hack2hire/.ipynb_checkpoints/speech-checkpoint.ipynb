# %%
import speech_recognition as sr
from gtts import gTTS
from pygame import mixer
import time

def fetch(txt,name):
    language="en"
    myob=gTTS(text=txt,lang=language,slow=False)
    myob.save(name)
    print(txt)
    mixer.init()
    mixer.music.load(name)
    mixer.music.play()
    
r = sr.Recognizer()
count=0
n=0
while n<100:
    with sr.Microphone() as source:
        name="voice"+str(count)+".mp3"
        print("Speak Anything :")
        audio = r.listen(source)
        n=n+1
        try:
            mtext = r.recognize_google(audio)
            print("You said : {}".format(mtext))
            fetch(mtext,name)
            time.sleep(10)
            count=count+1
        
        except:
            print("Sorry could not recognize what you said")
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Speak Anything :
# You said : hello
# hello
# Speak Anything :
# You said : hi
# hi
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# Sorry could not recognize what you said
# Speak Anything :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f3391c88c152> in <module>
#      20         name="voice"+str(count)+".mp3"
#      21         print("Speak Anything :")
# ---> 22         audio = r.listen(source)
#      23         n=n+1
#      24         try:
#
# D:\ANACONDASETUPFILE\lib\site-packages\speech_recognition\__init__.py in listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     650                     break
#     651
# --> 652                 buffer = source.stream.read(source.CHUNK)
#     653                 if len(buffer) == 0: break  # reached end of the stream
#     654                 frames.append(buffer)
#
# D:\ANACONDASETUPFILE\lib\site-packages\speech_recognition\__init__.py in read(self, size)
#     159
#     160         def read(self, size):
# --> 161             return self.pyaudio_stream.read(size, exception_on_overflow=False)
#     162
#     163         def close(self):
#
# D:\ANACONDASETUPFILE\lib\site-packages\pyaudio.py in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# KeyboardInterrupt:

# %%
def audiototext():
    import speech_recognition as sr
    r = sr.Recognizer()
    with sr.Microphone() as source:
        name="voice"+str(count)+".mp3"
        print("Speak Anything :")
        audio = r.listen(source)
        try:
            mtext = r.recognize_google(audio)
            #print("You said : {}".format(mtext))
            return(mtext)
        except:
            return("tinty")
x=audiototext()
